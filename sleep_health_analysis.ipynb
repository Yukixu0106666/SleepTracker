# %%
print("\n" + "=" * 80)
print("💡 应用于 SleepTracker App 的建议")
print("=" * 80)

print(\"\"\"\n✨ 基于数据规律的功能建议：\n\n\
1. 📊 **睡眠时长追踪**\n\
   - 数据显示各年龄段的睡眠需求不同\n\
   - 建议在 App 中提示用户年龄组的推荐睡眠时长\n\n\
2. 😰 **压力管理**\n\
   - 分析压力与睡眠的关系\n\
   - 高压力用户应获得特别的睡眠建议\n\n\
3. 🏃 **运动与睡眠**\n\
   - 追踪运动频率对睡眠质量的影响\n\
   - 建议用户保持适度运动\n\n\
4. ⚖️ **体重健康指数**\n\
   - BMI 与睡眠质量的关系\n\
   - 提供个性化的健康建议\n\n\
5. 💼 **职业因素**\n\
   - 不同职业的睡眠模式差异\n\
   - 针对性的改善方案\n\n\"\"\")\n\nprint(\"=" * 80)\nprint(\"✅ 分析完成！\")\nprint(\"\" * 80)")

# %%
print("=" * 80)
print("🔍 数据规律总结 - Sleep Health and Lifestyle Dataset")
print("=" * 80)

print("\n📈 数据总体情况：")
print(f"   • 样本数量: {len(df)} 个")
print(f"   • 特征数量: {df.shape[1]} 个")
print(f"   • 数值特征: {len(numeric_cols)} 个")
print(f"   • 分类特征: {len(categorical_cols)} 个")

print("\n🧮 关键统计指标：")
for col in numeric_cols[:3]:  # 展示前3个
    print(f"\n   📊 {col}:")
    print(f"      - 平均值: {df[col].mean():.2f}")
    print(f"      - 中位数: {df[col].median():.2f}")
    print(f"      - 标准差: {df[col].std():.2f}")
    print(f"      - 范围: [{df[col].min():.2f}, {df[col].max():.2f}]")

print("\n🔗 关键相关性发现：")
if strong_correlations:
    print(f"   • 发现 {len(strong_correlations)} 个强相关关系")
    for col1, col2, corr in sorted(strong_correlations, key=lambda x: abs(x[2]), reverse=True)[:5]:
        direction = "正相关 ✓" if corr > 0 else "负相关 ✗"
        strength = "很强" if abs(corr) > 0.7 else "较强"
        print(f"      - {col1} ↔ {col2}: {corr:.3f} ({strength}{direction})")
else:
    print("   • 未发现明显的强相关关系")

print("\n📊 分类特征分布：")
for col in categorical_cols[:2]:
    print(f"\n   📌 {col}:")
    value_counts = df[col].value_counts()
    for val, count in value_counts.head(3).items():
        pct = (count / len(df)) * 100
        print(f"      - {val}: {count} ({pct:.1f}%)")

# %% [markdown]
# ## 7️⃣ Key Insights and Patterns
# ### 🎯 数据规律发现总结

# %%
# 可视化相关系数热力图
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, 
            fmt='.2f', square=True, linewidths=1, cbar_kws={"shrink": 0.8})
plt.title('🔥 相关系数热力图', fontsize=16, fontweight='bold', pad=20)
plt.tight_layout()
plt.show()

print("\n✅ 热力图绘制完成！")

# %%
# 计算相关系数矩阵
correlation_matrix = numeric_df.corr()

print("📊 相关系数矩阵：\n")
print(correlation_matrix.round(3))

# 找出强相关关系
print("\n" + "=" * 80)
print("💡 强相关关系（相关系数 > 0.5 或 < -0.5）：\n")

strong_correlations = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        corr_value = correlation_matrix.iloc[i, j]
        if abs(corr_value) > 0.5:
            col1 = correlation_matrix.columns[i]
            col2 = correlation_matrix.columns[j]
            strong_correlations.append((col1, col2, corr_value))

if strong_correlations:
    for col1, col2, corr in sorted(strong_correlations, key=lambda x: abs(x[2]), reverse=True):
        direction = "正相关" if corr > 0 else "负相关"
        print(f"   {col1} ↔ {col2}: {corr:.3f} ({direction})")
else:
    print("   未找到强相关关系")

# %% [markdown]
# ## 6️⃣ Correlation Analysis
# ### 🔗 特征相关性矩阵分析

# %%
# 创建4: 数值列间的散点图（找关系）
if len(numeric_cols) >= 2:
    # 取前两个数值列进行散点图分析
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle('📍 特征间的散点图关系', fontsize=16, fontweight='bold')
    
    # 散点图1: 第1个vs第2个
    axes[0].scatter(df[numeric_cols[0]].dropna(), df[numeric_cols[1]].dropna(), 
                    alpha=0.6, s=50, color='green')
    axes[0].set_xlabel(numeric_cols[0])
    axes[0].set_ylabel(numeric_cols[1])
    axes[0].set_title(f'{numeric_cols[0]} vs {numeric_cols[1]}', fontweight='bold')
    axes[0].grid(True, alpha=0.3)
    
    # 如果有第3个数值列，再添加一个散点图
    if len(numeric_cols) >= 3:
        axes[1].scatter(df[numeric_cols[0]].dropna(), df[numeric_cols[2]].dropna(), 
                        alpha=0.6, s=50, color='purple')
        axes[1].set_xlabel(numeric_cols[0])
        axes[1].set_ylabel(numeric_cols[2])
        axes[1].set_title(f'{numeric_cols[0]} vs {numeric_cols[2]}', fontweight='bold')
    
    axes[1].grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    print("✅ 散点图绘制完成！\n")

# %%
# 创建3: 数值列的箱线图（用于发现异常值和分布特征）
if len(numeric_cols) > 0:
    fig, axes = plt.subplots(1, min(3, len(numeric_cols)), figsize=(16, 5))
    if len(numeric_cols) == 1:
        axes = [axes]
    
    fig.suptitle('📦 箱线图分析（异常值检测）', fontsize=16, fontweight='bold')
    
    for idx, col in enumerate(numeric_cols[:3]):
        sns.boxplot(y=df[col].dropna(), ax=axes[idx], color='lightblue')
        axes[idx].set_title(f'{col} 箱线图', fontweight='bold')
        axes[idx].set_ylabel(col)
    
    plt.tight_layout()
    plt.show()
    print("✅ 箱线图绘制完成！\n")

# %%
# 创建2: 分类变量分布
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
categorical_cols = [col for col in categorical_cols if col.lower() not in ['id', 'index']]

if len(categorical_cols) > 0:
    fig, axes = plt.subplots(1, min(3, len(categorical_cols)), figsize=(16, 4))
    if len(categorical_cols) == 1:
        axes = [axes]
    
    fig.suptitle('📊 分类特征分布分析', fontsize=16, fontweight='bold')
    
    for idx, col in enumerate(categorical_cols[:3]):
        value_counts = df[col].value_counts()
        axes[idx].bar(range(len(value_counts)), value_counts.values, color='coral', alpha=0.7)
        axes[idx].set_xticks(range(len(value_counts)))
        axes[idx].set_xticklabels(value_counts.index, rotation=45, ha='right')
        axes[idx].set_title(f'{col} 分布', fontweight='bold')
        axes[idx].set_ylabel('数量')
        axes[idx].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    print("✅ 分类变量分布绘制完成！\n")

# %%
# 获取可用的数值列（去掉ID等无意义列）
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
numeric_cols = [col for col in numeric_cols if col.lower() not in ['id', 'index']]

print(f"分析的数值列: {numeric_cols}\n")

# 创建1: 数值列的分布直方图
if len(numeric_cols) > 0:
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    fig.suptitle('🔍 数值特征分布分析', fontsize=16, fontweight='bold')
    axes = axes.flatten()
    
    for idx, col in enumerate(numeric_cols[:4]):  # 取前4个数值列
        if col in df.columns:
            axes[idx].hist(df[col].dropna(), bins=30, color='skyblue', edgecolor='black', alpha=0.7)
            axes[idx].set_title(f'{col} 分布', fontweight='bold')
            axes[idx].set_xlabel(col)
            axes[idx].set_ylabel('频数')
            axes[idx].grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    print("✅ 分布直方图绘制完成！\n")

# %% [markdown]
# ## 5️⃣ Exploratory Data Analysis with Visualizations
# ### 📈 多角度数据可视化

# %%
# 获取数值列进行统计分析
numeric_df = df.select_dtypes(include=[np.number])

print("📊 数值列统计摘要：\n")
print(numeric_df.describe().round(2))

print("\n" + "=" * 80)
print("逐列详细统计：\n")

for col in numeric_df.columns:
    print(f"📌 {col}:")
    print(f"   均值: {numeric_df[col].mean():.2f}")
    print(f"   中位数: {numeric_df[col].median():.2f}")
    print(f"   标准差: {numeric_df[col].std():.2f}")
    print(f"   最小值: {numeric_df[col].min():.2f}")
    print(f"   最大值: {numeric_df[col].max():.2f}")
    print()

# %% [markdown]
# ## 4️⃣ Descriptive Statistics
# ### 基础统计分析

# %%
# 数据清理
print("🧹 数据清理开始...\n")

# 检查缺失值
print("缺失值统计：")
missing = df.isnull().sum()
if missing.sum() == 0:
    print("✅ 无缺失值")
else:
    print(missing[missing > 0])

# 检查重复值
duplicates = df.duplicated().sum()
print(f"\n重复值统计: {duplicates} 条重复记录")
if duplicates > 0:
    df = df.drop_duplicates()
    print(f"✅ 已删除重复值，剩余 {len(df)} 条记录")

# 数据类型转换
print("\n📝 数据类型处理：")
# 尝试转换数值列
numeric_columns = df.select_dtypes(include=['object']).columns.tolist()
for col in numeric_columns:
    try:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    except:
        pass

print("✅ 数据清理完成！")
print(f"最终数据形状: {df.shape}")

# %% [markdown]
# ## 3️⃣ Data Preprocessing and Cleaning

# %%
# 显示数据集基本信息
print("🔍 数据集概览：\n")
print("=" * 80)
print("前5行数据：")
print(df.head())
print("\n" + "=" * 80)
print("列名和数据类型：")
print(df.info())
print("\n" + "=" * 80)
print("列名列表：")
print(df.columns.tolist())

# %%
# 尝试下载并加载数据集
import subprocess

# 检查数据文件是否存在
data_path = 'Sleep_health_and_lifestyle_dataset.csv'
if not os.path.exists(data_path):
    print("📥 正在尝试使用 Kaggle API 下载数据集...")
    try:
        # 尝试使用 Kaggle API
        subprocess.run(['kaggle', 'datasets', 'download', '-d', 'deadmau49/sleep-health-and-lifestyle-dataset', '-p', '.'], 
                       capture_output=True, text=True, timeout=30)
        
        # 解压文件
        import zipfile
        zip_file = 'sleep-health-and-lifestyle-dataset.zip'
        if os.path.exists(zip_file):
            with zipfile.ZipFile(zip_file, 'r') as zip_ref:
                zip_ref.extractall('.')
            print("✅ 数据集下载并解压成功！")
    except:
        print("⚠️ Kaggle API 下载失败。请手动下载数据集：")
        print("   1. 访问: https://www.kaggle.com/datasets/deadmau49/sleep-health-and-lifestyle-dataset")
        print("   2. 下载 CSV 文件到项目目录")
        print("   3. 重新运行此单元格")

# 加载数据集
if os.path.exists(data_path):
    df = pd.read_csv(data_path)
    print(f"✅ 数据集加载成功！")
    print(f"📊 数据形状: {df.shape[0]} 行, {df.shape[1]} 列\n")
else:
    print("❌ 未找到数据文件，请先下载数据集")

# %% [markdown]
# ## 2️⃣ Load and Explore the Dataset
#
# ### 📥 下载数据集说明：
# 1. **方法A (推荐)：** 访问 https://www.kaggle.com/datasets/deadmau49/sleep-health-and-lifestyle-dataset
# 2. **方法B：** 使用 Kaggle API: `kaggle datasets download -d deadmau49/sleep-health-and-lifestyle-dataset`
# 3. **文件位置：** 将 CSV 文件放在项目目录下

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

warnings.filterwarnings('ignore')

# Set style for better visualizations
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

print("✅ Libraries imported successfully!")

# %% [markdown]
# ## 1️⃣ Import Required Libraries

# %% [markdown]
# # Sleep Health and Lifestyle Dataset Analysis
# ## 📊 Kaggle数据集深度分析
# 分析睡眠健康与生活方式的关系，发现隐藏的数据规律
